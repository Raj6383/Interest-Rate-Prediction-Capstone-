# %%
import pandas as pd

# %%
train = pd.read_csv('Data/capstone_train.csv')
test = pd.read_csv('Data/capstone_test.csv')
combined_data = pd.concat((train,test),axis =0).drop('Loan_ID',axis = 1)
combined_data.head()
# Out:
#   Loan_Amount_Requested Length_Employed Home_Owner  Annual_Income  \
# 0                 7,000        < 1 year       Rent        68000.0
# 1                30,000         4 years   Mortgage            NaN
# 2                24,725         7 years   Mortgage        75566.4
# 3                16,000        < 1 year        NaN        56160.0
# 4                17,000         8 years        Own        96000.0
#
#             Income_Verified     Purpose_Of_Loan  Debt_To_Income  \
# 0              not verified                 car           18.37
# 1         VERIFIED - income  debt_consolidation           14.93
# 2  VERIFIED - income source  debt_consolidation           15.88
# 3  VERIFIED - income source  debt_consolidation           14.34
# 4  VERIFIED - income source  debt_consolidation           22.17
#
#    Inquiries_Last_6Mo  Months_Since_Deliquency  Number_Open_Accounts  \
# 0                   0                      NaN                     9
# ...

# %%
def remove_punctuation(x):
    if len(x.split(','))>1:
        return int(x.split(',')[0]+x.split(',')[1])
    else:
        return int(x)
combined_data['Loan_Amount_Requested'] = combined_data['Loan_Amount_Requested'].apply(remove_punctuation)

# %%
data_cpy = combined_data.copy()

# %%
#Manually replacing categories with numbers to preserve nan and let KNNImputer fill them
import numpy as np

for i in combined_data.select_dtypes('object').columns:
    unique = combined_data[i].dropna().unique()
    d = dict(zip(unique,list(range(len(unique)))))
    data_cpy[i] = data_cpy[i].map(d)
#To reverse

for i in combined_data.select_dtypes('object').columns:
    unique = combined_data[i].dropna().unique()
    d = dict(zip(list(range(len(unique))),unique))
    #Apply the data after knn_imputer to get the categorical features again

# %%
train_cpy = data_cpy[~(data_cpy['Interest_Rate'].isna())]
